# %% [markdown]
# ## The Australian Women on Labour Force During Covid Times

# %% [markdown]
# ### Polianna Moraes_Aug/22

# %% [markdown]
# #### Capstone Project from Data Analytics Immersive Course - General Assembly

# %% [markdown]
# ##### #1. Importing libraries

# %%
#!pip install psycopg2

# %%
import pandas as pd
import psycopg2
import sqlalchemy

# %% [markdown]
# ##### #2. Connecting to SQL

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:poppins11@localhost:5433/gender_gap_covid')

# %%
conn = psycopg2.connect(host = 'localhost', 
                       database = 'gender_gap_covid',
                       user = 'postgres',
                       password = 'poppins11',
                       port = 5433)

# %% [markdown]
# ##### #3. Exploring the Datasets
#
# - Connecting and reading CSVs Files
# - Transforming and formating data
# - Upload to Postgresql

# %% [markdown]
# ### Jobseeker by Gender

# %%
df = pd.read_csv('./Jobseeker Mar 2020 to Mar 2021.csv')
df.head()
# Out:
#        By Age Group March 2020 Females March 2020 Males April 2020 Females  \
# 0  Total Recipients            429,265          456,948            641,504
# 1    Under 25 years             72,919           89,047            125,060
# 2       25-34 years             63,062          103,021            125,382
# 3       35-44 years             79,912           87,568            114,956
# 4       45-54 years             97,971           82,462            132,651
#
#   April 2020 Males May 2020 Females May 2020 Males June 2020 Females  \
# 0          701,532          764,901        870,385           751,720
# 1          136,469          155,203        178,418           152,240
# 2          183,417          152,116        223,333           147,348
# 3          137,436          138,212        168,922           135,674
# 4          118,926          153,632        146,363           151,142
#
#   June 2020 Males July 2020 Females  ... November 2020 Females  \
# ...

# %%
df = df.iloc[1: , :]

# %%
df.head()
df.columns
# Out:
# Index(['By Age Group', 'March 2020 Females', 'March 2020 Males',
#        'April 2020 Females', 'April 2020 Males', 'May 2020 Females',
#        'May 2020 Males', 'June 2020 Females', 'June 2020 Males',
#        'July 2020 Females', 'July 2020 Males', 'August 2020 Females',
#        'August 2020 Males', 'September 2020 Females', 'September 2020 Males',
#        'October 2020 Females', 'October 2020 Males', 'November 2020 Females',
#        'November 2020 Males', 'December 2020 Females', 'December 2020 Males',
#        'January 2021 Females', 'January 2021 Males', 'February 2021 Females',
#        'February 2021 Males', 'March 2021 Females', 'March 2021 Males'],
#       dtype='object')

# %%
df_unpivot = pd.melt(df, id_vars =['By Age Group'], value_vars =['March 2020 Females', 'March 2020 Males',
       'April 2020 Females', 'April 2020 Males', 'May 2020 Females',
       'May 2020 Males', 'June 2020 Females', 'June 2020 Males',
       'July 2020 Females', 'July 2020 Males', 'August 2020 Females',
       'August 2020 Males', 'September 2020 Females', 'September 2020 Males',
       'October 2020 Females', 'October 2020 Males', 'November 2020 Females',
       'November 2020 Males', 'December 2020 Females', 'December 2020 Males',
       'January 2021 Females', 'January 2021 Males', 'February 2021 Females',
       'February 2021 Males', 'March 2021 Females', 'March 2021 Males'])

# %%
df_unpivot.head(100)
# Out:
#       By Age Group               variable    value
# 0   Under 25 years     March 2020 Females   72,919
# 1      25-34 years     March 2020 Females   63,062
# 2      35-44 years     March 2020 Females   79,912
# 3      45-54 years     March 2020 Females   97,971
# 4      55-64 years     March 2020 Females  103,038
# ..             ...                    ...      ...
# 95     65 and over     October 2020 Males   15,293
# 96  Under 25 years  November 2020 Females  129,849
# 97     25-34 years  November 2020 Females  130,607
# 98     35-44 years  November 2020 Females  126,140
# 99     45-54 years  November 2020 Females  143,666
#
# [100 rows x 3 columns]

# %%
df_unpivot.to_sql('jobseeker', con=engine, if_exists='replace');

# %%
#df[['A', 'B']] = df['AB'].str.split(' ', 1, expand=True)
df_unpivot[['Month','Year','Gender']] = df_unpivot['variable'].str.split(' ', 3, expand=True)

# %%
df_unpivot.head(100)
# Out:
#          age_group  recipients       Date   Gender
# 0   Under 25 years      72.919 2020-01-01  Females
# 1      25-34 years      63.062 2020-01-01  Females
# 2      35-44 years      79.912 2020-01-01  Females
# 3      45-54 years      97.971 2020-01-01  Females
# 4      55-64 years     103.038 2020-01-01  Females
# ..             ...         ...        ...      ...
# 95     65 and over      15.293 2020-01-01    Males
# 96  Under 25 years     129.849 2020-01-01  Females
# 97     25-34 years     130.607 2020-01-01  Females
# 98     35-44 years     126.140 2020-01-01  Females
# 99     45-54 years     143.666 2020-01-01  Females
#
# [100 rows x 4 columns]

# %%
df_unpivot.drop(['variable'], axis=1, inplace=True)
# #df.drop(['A'], axis=1)

# %%
df_unpivot = df_unpivot.rename(columns={'value': 'recipients', 'By Age Group': 'age_group'})

# %%
df_unpivot.head()
# Out:
#         age_group  recipients       Date   Gender
# 0  Under 25 years      72.919 2020-01-01  Females
# 1     25-34 years      63.062 2020-01-01  Females
# 2     35-44 years      79.912 2020-01-01  Females
# 3     45-54 years      97.971 2020-01-01  Females
# 4     55-64 years     103.038 2020-01-01  Females

# %%
# df_unpivot["Value"] = pd.to_numeric(df_unpivot["Value"], errors='ignore')
# df_unpivot.dtypes

# %%
#df_unpivot = df_unpivot.astype({"Value": float})

# %%
print(type(df_unpivot))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# df_unpivot["recipients"]=df_unpivot["recipients"].astype(int)
# #frame[‘DataFrame Column’]= frame[‘DataFrame Column’].map(str)
# #frame[‘DataFrame Column’]= frame[‘DataFrame Column’].astype(str)

# %%
# df_unpivot['Value'].str.strip()

# %%
df_unpivot['recipients']=df_unpivot['recipients'].str.replace(',','.')
#df['x']=df['x'].str.replace(',','')
df_unpivot.head(10)
# Out:
#      By Age Group recipients  Month  Year   Gender
# 0  Under 25 years     72.919  March  2020  Females
# 1     25-34 years     63.062  March  2020  Females
# 2     35-44 years     79.912  March  2020  Females
# 3     45-54 years     97.971  March  2020  Females
# 4     55-64 years    103.038  March  2020  Females
# 5     65 and over     12.363  March  2020  Females
# 6  Under 25 years     89.047  March  2020    Males
# 7     25-34 years    103.021  March  2020    Males
# 8     35-44 years     87.568  March  2020    Males
# 9     45-54 years     82.462  March  2020    Males

# %%
df_unpivot["recipients"]=df_unpivot["recipients"].astype(float)
#frame[‘DataFrame Column’]= frame[‘DataFrame Column’].map(str)
#frame[‘DataFrame Column’]= frame[‘DataFrame Column’].astype(str)
df_unpivot.dtypes
# Out:
# By Age Group     object
# recipients      float64
# Month            object
# Year             object
# Gender           object
# dtype: object

# %%
df_unpivot['Year'] = pd.to_datetime(df_unpivot['Year'].astype(str),format='%Y%')

# pd.to_datetime(df_sub['year'].astype(str)  + df_sub['Months'], format='%Y%B')
df_unpivot.head(100)
# Out:
#       By Age Group  recipients     Month       Year   Gender
# 0   Under 25 years      72.919     March 2020-01-01  Females
# 1      25-34 years      63.062     March 2020-01-01  Females
# 2      35-44 years      79.912     March 2020-01-01  Females
# 3      45-54 years      97.971     March 2020-01-01  Females
# 4      55-64 years     103.038     March 2020-01-01  Females
# ..             ...         ...       ...        ...      ...
# 95     65 and over      15.293   October 2020-01-01    Males
# 96  Under 25 years     129.849  November 2020-01-01  Females
# 97     25-34 years     130.607  November 2020-01-01  Females
# 98     35-44 years     126.140  November 2020-01-01  Females
# 99     45-54 years     143.666  November 2020-01-01  Females
#
# [100 rows x 5 columns]

# %%
df_unpivot.drop(['Month'], axis=1, inplace=True)

# %%
df_unpivot.head(100)
# Out:
#       By Age Group  recipients       Year   Gender
# 0   Under 25 years      72.919 2020-01-01  Females
# 1      25-34 years      63.062 2020-01-01  Females
# 2      35-44 years      79.912 2020-01-01  Females
# 3      45-54 years      97.971 2020-01-01  Females
# 4      55-64 years     103.038 2020-01-01  Females
# ..             ...         ...        ...      ...
# 95     65 and over      15.293 2020-01-01    Males
# 96  Under 25 years     129.849 2020-01-01  Females
# 97     25-34 years     130.607 2020-01-01  Females
# 98     35-44 years     126.140 2020-01-01  Females
# 99     45-54 years     143.666 2020-01-01  Females
#
# [100 rows x 4 columns]

# %%
df_unpivot.rename(columns = {'Year':'Date'}, inplace = True)

# %%
df_unpivot.columns
# Out:
# Index(['age_group', 'recipients', 'Date', 'Gender'], dtype='object')

# %%
df_unpivot =
# Out:
#           age_group  recipients       Date   Gender
# 0    Under 25 years      72.919 2020-01-01  Females
# 1       25-34 years      63.062 2020-01-01  Females
# 2       35-44 years      79.912 2020-01-01  Females
# 3       45-54 years      97.971 2020-01-01  Females
# 4       55-64 years     103.038 2020-01-01  Females
# ..              ...         ...        ...      ...
# 151     25-34 years     163.181 2021-01-01    Males
# 152     35-44 years     129.149 2021-01-01    Males
# 153     45-54 years     118.146 2021-01-01    Males
# 154     55-64 years     118.574 2021-01-01    Males
# 155     65 and over      14.521 2021-01-01    Males
#
# [156 rows x 4 columns]

# %% [markdown]
# ### Earnings Weekly by gender

# %%
df_earnings_cleaned = pd.read_csv('./Earnings_cleaned.csv')
df_earnings_cleaned.head()
# Out:
#          Date  Earnings; Males; Full Time; Adult; Total earnings ;  \
# 0  2012-05-15                                             1537.1
# 1  2012-11-15                                             1578.3
# 2  2013-05-15                                             1605.5
# 3  2013-11-15                                             1619.5
# 4  2014-05-15                                             1650.5
#
#    Earnings; Females; Full Time; Adult; Total earnings ;
# 0                                             1209.1
# 1                                             1244.2
# 2                                             1269.2
# 3                                             1285.4
# 4                                             1293.7

# %%
df_earnings_cleaned.dtypes
# Out:
# Date                                                      object
# Earnings; Males; Full Time; Adult; Total earnings ;      float64
# Earnings; Females; Full Time; Adult; Total earnings ;    float64
# dtype: object

# %%
weekly_earnings_fulltime = df_earnings_cleaned

# %%
weekly_earnings_fulltime.rename(columns = {'Earnings; Males; Full Time; Adult; Total earnings ;':'Male', 'Earnings; Females; Full Time; Adult; Total earnings ;':'Female' },inplace = True)

# %%
weekly_earnings_fulltime.head()
# Out:
#         Date    Male  Female
# 0 2012-05-15  1537.1  1209.1
# 1 2012-11-15  1578.3  1244.2
# 2 2013-05-15  1605.5  1269.2
# 3 2013-11-15  1619.5  1285.4
# 4 2014-05-15  1650.5  1293.7

# %%
weekly_earnings_fulltime['Date'] = pd.to_datetime(weekly_earnings_fulltime['Date'].astype(str),format='%Y/%m/%d')

# %%
weekly_earnings_fulltime.dtypes
# Out:
# Date      datetime64[ns]
# Male             float64
# Female           float64
# dtype: object

# %%
weekly_earnings_fulltime["Male"]=weekly_earnings_fulltime["Male"].str.replace(',','.')
# Out:
# /var/folders/cv/47ztmd5d6c31ffxg8p8xbzl80000gp/T/ipykernel_46969/3845171319.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   weekly_earnings_fulltime["Male"]=weekly_earnings_fulltime["Male"].str.replace('$','')

# %%
weekly_earnings_fulltime["Female"]=weekly_earnings_fulltime["Female"].str.replace(',','.')
# Out:
# /var/folders/cv/47ztmd5d6c31ffxg8p8xbzl80000gp/T/ipykernel_46969/286755936.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   weekly_earnings_fulltime["Female"]=weekly_earnings_fulltime["Female"].str.replace('$',' ')

# %%
weekly_earnings_fulltime.head()
# Out:
#         Date    Male  Female
# 0 2012-05-15  1537.1  1209.1
# 1 2012-11-15  1578.3  1244.2
# 2 2013-05-15  1605.5  1269.2
# 3 2013-11-15  1619.5  1285.4
# 4 2014-05-15  1650.5  1293.7

# %%
weekly_earnings_fulltime["Male"]=weekly_earnings_fulltime["Male"].astype(float)
weekly_earnings_fulltime["Female"]=weekly_earnings_fulltime["Female"].astype(float)

# %%
weekly_earnings_fulltime.columns
# Out:
# Index(['Date', 'Male', 'Female'], dtype='object')

# %%
weekly_earnings_fulltime.to_sql('weekly_earning_fulltime_2015_2022', con=engine)
# Out:
# 20

# %% [markdown]
# ### Weekly earnings by method pay

# %%
weekly_earnings_method = pd.read_csv('./weekly_earnings_by type emp.csv')
weekly_earnings_method.head()
# Out:
#                       Method of setting pay Full-time employees Males  \
# 0                                     Award                       561
# 1                      Collective agreement                     1,248
# 2                    Individual arrangement                     2,176
# 3  Owner manager of incorporated enterprise                       292
# 4                All methods of setting pay                     4,277
#
#   Part-time employees Males Full-time employees Females  \
# 0                       527                         433
# 1                       518                       1,020
# 2                       353                       1,123
# 3                        63                          68
# 4                     1,462                       2,644
#
#   Part-time employees Females  Full-time Males Avg Age  \
# 0                       1,138                       36
# 1                       1,281                       44
# ...

# %%
weekly_earnings_method = weekly_earnings_method.rename(columns={'Method of setting pay': 'method_setting_pay'})

# %%
weekly_earnings_method.columns
# Out:
# Index(['Method of setting pay', 'variable', 'value'], dtype='object')

# %%
weekly_earnings_method['Full-time employees Males']=weekly_earnings_method['Full-time employees Males'].str.replace(',','.')
weekly_earnings_method['Part-time employees Males']=weekly_earnings_method['Part-time employees Males'].str.replace(',','.')
weekly_earnings_method['Full-time employees Females']=weekly_earnings_method['Full-time employees Females'].str.replace(',','.')
weekly_earnings_method['Part-time employees Females']=weekly_earnings_method['Part-time employees Females'].str.replace(',','.')

# %%
weekly_earnings_method = weekly_earnings_method.apply(pd.to_numeric, errors='ignore', downcast='float')
weekly_earnings_method.dtypes
# Out:
# Method of setting pay           object
# Full-time employees Males      float32
# Part-time employees Males      float32
# Full-time employees Females    float32
# Part-time employees Females    float32
# Full-time Males Avg Age        float32
# Part-time  Males Avg Age       float32
# Full-time  Females Avg Age     float32
# Part-time Females Avg Age      float32
# dtype: object

# %%
weekly_earnings_method.head()
# Out:
#                       Method of setting pay  Full-time employees Males  \
# 0                                     Award                    561.000
# 1                      Collective agreement                      1.248
# 2                    Individual arrangement                      2.176
# 3  Owner manager of incorporated enterprise                    292.000
# 4                All methods of setting pay                      4.277
#
#    Part-time employees Males  Full-time employees Females  \
# 0                    527.000                      433.000
# 1                    518.000                        1.020
# 2                    353.000                        1.123
# 3                     63.000                       68.000
# 4                      1.462                        2.644
#
#    Part-time employees Females  Full-time Males Avg Age  \
# 0                        1.138                     36.0
# 1                        1.281                     44.0
# ...

# %%
weekly_earnings_method = pd.melt(weekly_earnings_method, id_vars =['Method of setting pay'], value_vars =['Full-time employees Males',
       'Part-time employees Males', 'Full-time employees Females',
       'Part-time employees Females', 'Full-time Males Avg Age',
       'Part-time  Males Avg Age', 'Full-time  Females Avg Age',
       'Part-time Females Avg Age'])

# %%
weekly_earnings_method.to_sql('weekly_employees_method_pay', con=engine,if_exists='replace');

# %% [markdown]
# ### Weekly Earning by contract (permanent or casual)

# %%
weekly_earnings_contract = pd.read_csv('./weekly_earning_contract.csv')
weekly_earnings_contract.head()
# Out:
#                       Method of setting pay  \
# 0                                     Award
# 1                      Collective agreement
# 2                    Individual arrangement
# 3  Owner manager of incorporated enterprise
# 4                All methods of setting pay
#
#   Permanent or fixed term employees Male Casual employees Male  \
# 0                                    642                   447
# 1                                  1,472                   295
# 2                                  2,232                   298
# 3                                    354                     0
# 4                                  4,699                 1,039
#
#   Permanent or fixed term employees Female Casual employees Female  \
# 0                                      808                     763
# 1                                    1,944                     357
# 2                                    1,562                     281
# ...

# %%
weekly_earnings_contract = weekly_earnings_contract.rename(columns={'Method of setting pay': 'method_setting_pay'})

# %%
weekly_earnings_contract.columns
# Out:
# Index(['method_setting_pay', 'variable', 'value'], dtype='object')

# %%
weekly_earnings_contract.dtypes
# Out:
# Method of setting pay                               object
# Permanent or fixed term employees Male              object
# Casual employees Male                               object
# Permanent or fixed term employees Female            object
# Casual employees Female                             object
# Permanent or fixed term employees Male Avg Age       int64
# Casual employees Male Avg Age                        int64
# Permanent or fixed term employees Female Avg Age     int64
# Casual employees Female Avg Age                      int64
# dtype: object

# %%
weekly_earnings_contract['Permanent or fixed term employees Male']=weekly_earnings_contract['Permanent or fixed term employees Male'].str.replace(',','.')
weekly_earnings_contract['Casual employees Male']=weekly_earnings_contract['Casual employees Male'].str.replace(',','.')
weekly_earnings_contract['Permanent or fixed term employees Female']=weekly_earnings_contract['Permanent or fixed term employees Female'].str.replace(',','.')
weekly_earnings_contract['Casual employees Female']=weekly_earnings_contract['Casual employees Female'].str.replace(',','.')

# %%
weekly_earnings_contract = pd.melt(weekly_earnings_contract, id_vars =['Method of setting pay'], value_vars =['Permanent or fixed term employees Male',
       'Casual employees Male', 'Permanent or fixed term employees Female',
       'Casual employees Female',
       'Permanent or fixed term employees Male Avg Age',
       'Casual employees Male Avg Age',
       'Permanent or fixed term employees Female Avg Age',
       'Casual employees Female Avg Age'])

# %%
weekly_earnings_contract = weekly_earnings_contract.apply(pd.to_numeric, errors='ignore', downcast='float');

# %%
weekly_earnings_contract.head()
# Out:
#                       Method of setting pay  \
# 0                                     Award
# 1                      Collective agreement
# 2                    Individual arrangement
# 3  Owner manager of incorporated enterprise
# 4                All methods of setting pay
#
#   Permanent or fixed term employees Male Casual employees Male  \
# 0                                    642                   447
# 1                                  1.472                   295
# 2                                  2.232                   298
# 3                                    354                     0
# 4                                  4.699                 1.039
#
#   Permanent or fixed term employees Female Casual employees Female  \
# 0                                      808                     763
# 1                                    1.944                     357
# 2                                    1.562                     281
# ...

# %%
weekly_earnings_contract.dtypes
# Out:
# Method of setting pay                                object
# Permanent or fixed term employees Male              float32
# Casual employees Male                               float32
# Permanent or fixed term employees Female            float32
# Casual employees Female                             float32
# Permanent or fixed term employees Male Avg Age      float32
# Casual employees Male Avg Age                       float32
# Permanent or fixed term employees Female Avg Age    float32
# Casual employees Female Avg Age                     float32
# dtype: object

# %%
weekly_earnings_contract.to_sql('weekly_employees_contract', con=engine,  if_exists='replace');

# %% [markdown]
# ### Weekly Earning by Gender

# %%
weekly_earnings_gender = pd.read_csv('./weekly_earning_gender.csv')
weekly_earnings_gender.head()
# Out:
#                       Method of setting pay  \
# 0                                     Award
# 1                      Collective agreement
# 2                    Individual arrangement
# 3  Owner manager of incorporated enterprise
# 4                All methods of setting pay
#
#   Permanent or fixed term employees Male Casual employees Male  \
# 0                                  1,139                   648
# 1                                  1,851                   857
# 2                                  1,965                 1,267
# 3                                  1,603                     0
# 4                                  1,789                   885
#
#   Permanent or fixed term employees Female  Casual employees Female  \
# 0                                    1,030                      533
# 1                                    1,403                      544
# 2                                    1,479                      722
# ...

# %%
weekly_earnings_gender = weekly_earnings_gender.rename(columns={'Method of setting pay': 'method_setting_pay'})

# %%
weekly_earnings_gender.columns
# Out:
# Index(['Method of setting pay', 'variable', 'value'], dtype='object')

# %%
weekly_earnings_gender.dtypes
# Out:
# Method of setting pay                       object
# Permanent or fixed term employees Male      object
# Casual employees Male                       object
# Permanent or fixed term employees Female    object
# Casual employees Female                      int64
# Full-time employees Male                    object
# Part-time employees Male                     int64
# Full-time employees Female                  object
# Part-time employees Female                   int64
# dtype: object

# %%
# weekly_earnings_gender['Permanent or fixed term employees Male']=weekly_earnings_gender['Permanent or fixed term employees Male'].str.replace(',','.')
# weekly_earnings_gender['Casual employees Male']=weekly_earnings_gender['Casual employees Male'].str.replace(',','.')
# weekly_earnings_gender['Permanent or fixed term employees Female']=weekly_earnings_gender['Permanent or fixed term employees Female'].str.replace(',','.')
# weekly_earnings_gender['Full-time employees Male']=weekly_earnings_gender['Full-time employees Male'].str.replace(',','.')
weekly_earnings_gender['Full-time employees Female']=weekly_earnings_gender['Full-time employees Female'].str.replace(',','.')

# %%
weekly_earnings_gender.head()
# Out:
#                       Method of setting pay  \
# 0                                     Award
# 1                      Collective agreement
# 2                    Individual arrangement
# 3  Owner manager of incorporated enterprise
# 4                All methods of setting pay
#
#    Permanent or fixed term employees Male  Casual employees Male  \
# 0                                   1.139                648.000
# 1                                   1.851                857.000
# 2                                   1.965                  1.267
# 3                                   1.603                  0.000
# 4                                   1.789                885.000
#
#    Permanent or fixed term employees Female  Casual employees Female  \
# 0                                     1.030                      533
# 1                                     1.403                      544
# 2                                     1.479                      722
# ...

# %%
weekly_earnings_gender['Permanent or fixed term employees Male']=weekly_earnings_gender['Permanent or fixed term employees Male'].astype(float)
weekly_earnings_gender['Casual employees Male']=weekly_earnings_gender['Casual employees Male'].astype(float)
weekly_earnings_gender['Permanent or fixed term employees Female']=weekly_earnings_gender['Permanent or fixed term employees Female'].astype(float)
weekly_earnings_gender['Full-time employees Male']=weekly_earnings_gender['Full-time employees Male'].astype(float)
weekly_earnings_gender['Full-time employees Female  ']=weekly_earnings_gender['Full-time employees Female'].astype(float)

# %%
weekly_earnings_gender.dtypes
# Out:
# Method of setting pay                        object
# Permanent or fixed term employees Male      float64
# Casual employees Male                       float64
# Permanent or fixed term employees Female    float64
# Casual employees Female                       int64
# Full-time employees Male                    float64
# Part-time employees Male                      int64
# Full-time employees Female                   object
# Part-time employees Female                    int64
# Full-time employees Female                   object
# dtype: object

# %%
weekly_earnings_gender.columns
# Out:
# Index(['Method of setting pay', 'variable', 'value'], dtype='object')

# %%
weekly_earnings_gender = pd.melt(weekly_earnings_gender, id_vars =['Method of setting pay'], value_vars =['Permanent or fixed term employees Male',
       'Casual employees Male', 'Permanent or fixed term employees Female',
       'Casual employees Female', 'Full-time employees Male',
       'Part-time employees Male', 'Full-time employees Female',
       'Part-time employees Female', 'Full-time employees Female'])

# %%
weekly_earnings_gender.to_sql('weekly_earnings_gender', con=engine,  if_exists='replace');

# %% [markdown]
# ### Employment Ratio by Gender

# %%
employment_ratio_2012_2022 = pd.read_csv('./Employment_population_ratio_2012_2022.csv')

# %%
employment_ratio_2012_2022.columns
# Out:
# Index(['Date', 'People (%)', 'Males (%)', 'Females (%)'], dtype='object')

# %%
employment_ratio_2012_2022.dtypes
# Out:
# Date           datetime64[ns]
# People (%)            float64
# Males (%)             float64
# Females (%)           float64
# dtype: object

# %%
employment_ratio_2012_2022.head()
# Out:
#         Date  People (%)  Males (%)  Females (%)
# 0 2012-06-01        61.7       68.1         55.6
# 1 2012-07-01        61.7       67.8         55.7
# 2 2012-08-01        61.7       67.8         55.7
# 3 2012-09-01        61.7       67.7         55.9
# 4 2012-10-01        61.7       67.9         55.5

# %%
employment_ratio_2012_2022['Date'] = pd.to_datetime(employment_ratio_2012_2022['Date'].astype(str),format='%Y/%m/%d')

# %%
employment_ratio_2012_2022.to_sql('employment_ratio_2012_2022', con=engine,  if_exists='replace');

# %% [markdown]
# ### Participation on Labour Force

# %%
participation_labourforce_2012_2022 = pd.read_csv('./Participation_rate_2012_2022.csv')

participation_labourforce_2012_2022.head()
# Out:
#          Date  People (%)  Males (%)  Females (%)
# 0  2012-06-01        65.1       71.6         58.8
# 1  2012-07-01        65.1       71.5         58.8
# 2  2012-08-01        65.0       71.6         58.6
# 3  2012-09-01        65.3       71.8         59.0
# 4  2012-10-01        65.2       71.8         58.8

# %%
participation_labourforce_2012_2022['Date'] = pd.to_datetime(participation_labourforce_2012_2022['Date'].astype(str),format='%Y/%m/%d')

# %%
participation_labourforce_2012_2022.to_sql('participation_labourforce_2012_2022', con=engine,  if_exists='replace');

# %% [markdown]
# ### Underployment Rate by Gender

# %%
underployment_rate_2012_2022 = pd.read_csv('./Underemployment_rate_2012_2021.csv')
underployment_rate_2012_2022.info
# Out:
# <bound method DataFrame.info of            Date  People (%)  Males (%)  Females (%)
# 0    2012-06-01         7.2        5.4          9.3
# 1    2012-07-01         7.1        5.2          9.2
# 2    2012-08-01         6.9        5.1          9.0
# 3    2012-09-01         6.8        5.1          8.9
# 4    2012-10-01         7.0        5.2          9.1
# ..          ...         ...        ...          ...
# 116  2022-02-01         6.6        5.4          7.8
# 117  2022-03-01         6.4        5.1          7.8
# 118  2022-04-01         6.1        5.0          7.4
# 119  2022-05-01         5.7        4.7          6.9
# 120  2022-06-01         6.1        5.1          7.2
#
# [121 rows x 4 columns]>

# %%
underployment_rate_2012_2022.columns
# Out:
# Index(['Date', 'People (%)', 'Males (%)', 'Females (%)'], dtype='object')

# %%
underployment_rate_2012_2022['Date'] = pd.to_datetime(underployment_rate_2012_2022['Date'].astype(str),format='%Y/%m/%d')

# %%
underployment_rate_2012_2022.to_sql('underployment_rate_2012_2022', con=engine,  if_exists='replace');

# %% [markdown]
# ### Unemployment by Gender

# %%
unemployment_gender = pd.read_csv('./Unemployed_gender.csv')
unemployment_gender.head()
# Out:
#          Date  Unemployed Males   Unemployed Females
# 0  1978-02-01              231.4                195.5
# 1  1978-03-01              217.6                186.2
# 2  1978-04-01              220.4                182.9
# 3  1978-05-01              215.2                184.2
# 4  1978-06-01              225.6                180.3

# %%
unemployment_gender.dtypes
# Out:
# Date                   datetime64[ns]
# Unemployed Males              float64
# Unemployed Females            float64
# dtype: object

# %%
unemployment_gender['Date'] = pd.to_datetime(unemployment_gender['Date'].astype(str),format='%Y/%m/%d')

# %%
unemployment_gender.to_sql('unemployment_gender', con=engine,  if_exists='replace');

# %% [markdown]
# ### Industries by Gender 2010 to 2020

# %%
industries_gender_2010_2020 = pd.read_csv('./industries_gender_2010_2020.csv')

# %%
industries_gender_2010_2020.head()
# Out:
#                        Employment by industry  Males_2010  Females_2010  \
# 0           Agriculture, forestry and fishing       221.9         103.2
# 1                                      Mining       145.0          23.8
# 2                               Manufacturing       693.1         250.3
# 3  Electricity, gas, water and waste services       100.9          27.4
# 4                                Construction       821.4         114.4
#
#    Males_2011  Females_2011  Males_2012  Females_2012  Males_2013  \
# 0       213.6         102.2       207.5          92.7       192.5
# 1       168.8          30.8       204.9          37.9       223.7
# 2       690.4         238.8       667.1         227.2       659.8
# 3       112.6          33.1       111.7          36.1       107.9
# 4       833.7         113.4       836.8         113.9       825.5
#
#    Females_2013  Males_2014  ...  Males_2016  Females_2016  Males_2017  \
# ...

# %%
industries_gender_2010_2020.Gender
# Out:
# 0        Males
# 1        Males
# 2        Males
# 3        Males
# 4        Males
#         ...
# 435    Females
# 436    Females
# 437    Females
# 438    Females
# 439    Females
# Name: Gender, Length: 440, dtype: object

# %%
industries_gender_2010_2020 = pd.melt(industries_gender_2010_2020, id_vars =['Employment by industry'], value_vars =['Males_2010', 'Females_2010', 'Males_2011',
       'Females_2011', 'Males_2012', 'Females_2012', 'Males_2013',
       'Females_2013', 'Males_2014', 'Females_2014', 'Males_2015',
       'Females_2015', 'Males_2016', 'Females_2016', 'Males_2017',
       'Females_2017', 'Males_2018', 'Females_2018', 'Males_2019',
       'Females_2019', 'Males_2020', 'Females_2020'])

# %%
industries_gender_2010_2020.head(100)
# Out:
#                         Employment by industry   value Gender       Year
# 0            Agriculture, forestry and fishing   221.9  Males 2010-01-01
# 1                                       Mining   145.0  Males 2010-01-01
# 2                                Manufacturing   693.1  Males 2010-01-01
# 3   Electricity, gas, water and waste services   100.9  Males 2010-01-01
# 4                                 Construction   821.4  Males 2010-01-01
# ..                                         ...     ...    ...        ...
# 95                      Education and training   253.9  Males 2012-01-01
# 96           Health care and social assistance   281.5  Males 2012-01-01
# 97                Arts and recreation services    96.1  Males 2012-01-01
# 98                              Other services   241.0  Males 2012-01-01
# 99                      Total (all industries)  5770.3  Males 2012-01-01
#
# [100 rows x 4 columns]

# %%
industries_gender_2010_2020['variable']=industries_gender_2010_2020['variable'].str.replace('_',' ')

#weekly_earnings_gender['Permanent or fixed term employees Male']=weekly_earnings_gender['Permanent or fixed term employees Male'].str.replace(',','.')

# %%
industries_gender_2010_2020[['Gender', 'Year']] = industries_gender_2010_2020['variable'].str.split(' ', 2, expand=True)

# %%
industries_gender_2010_2020.head(10)
# Out:
#                        Employment by industry    variable  value Gender  Year
# 0           Agriculture, forestry and fishing  Males 2010  221.9  Males  2010
# 1                                      Mining  Males 2010  145.0  Males  2010
# 2                               Manufacturing  Males 2010  693.1  Males  2010
# 3  Electricity, gas, water and waste services  Males 2010  100.9  Males  2010
# 4                                Construction  Males 2010  821.4  Males  2010
# 5                             Wholesale trade  Males 2010  276.4  Males  2010
# 6                                Retail trade  Males 2010  424.6  Males  2010
# 7             Accommodation and food services  Males 2010  248.3  Males  2010
# 8           Transport, postal and warehousing  Males 2010  430.7  Males  2010
# 9    Information media and telecommunications  Males 2010  115.8  Males  2010

# %%
industries_gender_2010_2020.drop(['variable'], axis=1, inplace=True)
industries_gender_2010_2020.head(10)
# Out:
#                        Employment by industry  value Gender  Year
# 0           Agriculture, forestry and fishing  221.9  Males  2010
# 1                                      Mining  145.0  Males  2010
# 2                               Manufacturing  693.1  Males  2010
# 3  Electricity, gas, water and waste services  100.9  Males  2010
# 4                                Construction  821.4  Males  2010
# 5                             Wholesale trade  276.4  Males  2010
# 6                                Retail trade  424.6  Males  2010
# 7             Accommodation and food services  248.3  Males  2010
# 8           Transport, postal and warehousing  430.7  Males  2010
# 9    Information media and telecommunications  115.8  Males  2010

# %%
industries_gender_2010_2020.dtypes
# Out:
# Employment by industry            object
# value                            float64
# Gender                            object
# Year                      datetime64[ns]
# dtype: object

# %%
industries_gender_2010_2020['Year'] = pd.to_datetime(industries_gender_2010_2020['Year'].astype(str),format='%Y')

# %%
industries_gender_2010_2020.to_sql('industries_gender_2010_2020', con=engine,  if_exists='replace');

# %% [markdown]
# ### Occupation by Gender 2010 to 2020

# %%
occupation_gender_2010_2020 = pd.read_csv('./occupation_gender_2010_2020.csv')
occupation_gender_2010_2020.head()
# Out:
#                    Employment by industry  Males_2010  Females_2010  \
# 0                                Managers       936.7         486.3
# 1                           Professionals      1117.1        1205.4
# 2          Technicians and trades workers      1274.5         198.7
# 3  Community and personal service workers       283.0         619.5
# 4     Clerical and administrative workers       388.1        1186.9
#
#    Males_2011  Females_2011  Males_2012  Females_2012  Males_2013  \
# 0       924.1         482.8       933.5         506.0       924.2
# 1      1140.8        1257.8      1163.7        1277.6      1190.2
# 2      1340.6         201.5      1330.3         211.3      1345.6
# 3       299.4         652.4       314.0         662.0       321.9
# 4       393.4        1189.2       398.6        1236.4       398.0
#
#    Females_2013  Males_2014  ...  Males_2016  Females_2016  Males_2017  \
# 0         493.1       945.3  ...       969.5         550.1       964.2
# ...

# %%
occupation_gender_2010_2020.columns
# Out:
# Index(['Employment by industry', 'Males_2010', 'Females_2010', 'Males_2011',
#        'Females_2011', 'Males_2012', 'Females_2012', 'Males_2013',
#        'Females_2013', 'Males_2014', 'Females_2014', 'Males_2015',
#        'Females_2015', 'Males_2016', 'Females_2016', 'Males_2017',
#        'Females_2017', 'Males_2018', 'Females_2018', 'Males_2019',
#        'Females_2019', 'Males_2020', 'Females_2020'],
#       dtype='object')

# %%
occupation_gender_2010_2020 = pd.melt(occupation_gender_2010_2020, id_vars =['Employment by industry'], value_vars =['Males_2010', 'Females_2010', 'Males_2011',
       'Females_2011', 'Males_2012', 'Females_2012', 'Males_2013',
       'Females_2013', 'Males_2014', 'Females_2014', 'Males_2015',
       'Females_2015', 'Males_2016', 'Females_2016', 'Males_2017',
       'Females_2017', 'Males_2018', 'Females_2018', 'Males_2019',
       'Females_2019', 'Males_2020', 'Females_2020'])

# %%
occupation_gender_2010_2020.head()
# Out:
#                    Employment by industry    variable   value
# 0                                Managers  Males_2010   936.7
# 1                           Professionals  Males_2010  1117.1
# 2          Technicians and trades workers  Males_2010  1274.5
# 3  Community and personal service workers  Males_2010   283.0
# 4     Clerical and administrative workers  Males_2010   388.1

# %%
occupation_gender_2010_2020['variable']=occupation_gender_2010_2020['variable'].str.replace('_',' ')

# %%
occupation_gender_2010_2020.head()
# Out:
#                    Employment by industry    variable   value Gender  Year
# 0                                Managers  Males 2010   936.7  Males  2010
# 1                           Professionals  Males 2010  1117.1  Males  2010
# 2          Technicians and trades workers  Males 2010  1274.5  Males  2010
# 3  Community and personal service workers  Males 2010   283.0  Males  2010
# 4     Clerical and administrative workers  Males 2010   388.1  Males  2010

# %%
occupation_gender_2010_2020[['Gender', 'Year']] = occupation_gender_2010_2020['variable'].str.split(' ', 2, expand=True)

# %%
occupation_gender_2010_2020.drop(['variable'], axis=1, inplace=True)

# %%
occupation_gender_2010_2020['Year'] = pd.to_datetime(occupation_gender_2010_2020['Year'].astype(str),format='%Y')

# %%
occupation_gender_2010_2020.head(50)
# Out:
#                     Employment by industry   value   Gender       Year
# 0                                 Managers   936.7    Males 2010-01-01
# 1                            Professionals  1117.1    Males 2010-01-01
# 2           Technicians and trades workers  1274.5    Males 2010-01-01
# 3   Community and personal service workers   283.0    Males 2010-01-01
# 4      Clerical and administrative workers   388.1    Males 2010-01-01
# 5                            Sales workers   311.5    Males 2010-01-01
# 6          Machinery operators and drivers   614.0    Males 2010-01-01
# 7                                Labourers   639.7    Males 2010-01-01
# 8                  Total (all occupations)  5564.7    Males 2010-01-01
# 9                                 Managers   486.3  Females 2010-01-01
# 10                           Professionals  1205.4  Females 2010-01-01
# 11          Technicians and trades workers   198.7  Females 2010-01-01
# ...

# %%
occupation_gender_2010_2020.to_sql('occupation_gender_2010_2020', con=engine,  if_exists='replace');

# %%
not_labour_force_1991_2022 = pd.read_csv('./not_labour_force_1991_2022.csv')
not_labour_force_1991_2022.head()
# Out:
#          Date Gender          Age  \
# 0  1991-01-01  Males  15-24 years
# 1  1991-01-01  Males  15-24 years
# 2  1991-01-01  Males  15-24 years
# 3  1991-01-01  Males  15-24 years
# 4  1991-01-01  Males  15-24 years
#
#                       Reason not in the labour force  Not in Labour Force
# 0  Actively looked for work but unavailable to st...                6.595
# 1  Waiting to start work in 4 weeks or more [1991...                0.248
# 2  Waiting to start work, unavailable to start, b...                0.468
# 3                          Passively looked for work               12.473
# 4                              Did not look for work              294.394

# %%
not_labour_force_1991_2022['Date'] = pd.to_datetime(not_labour_force_1991_2022['Date'].astype(str),format='%Y/%m/%d')

# %%
not_labour_force_1991_2022.dtypes
# Out:
# Date                              datetime64[ns]
# Gender                                    object
# Age                                       object
# Reason not in the labour force            object
# Not in Labour Force                      float64
# dtype: object

# %%
not_labour_force_1991_2022.to_sql('not_labour_force_1991_2022', con=engine,  if_exists='replace');

# %% [markdown]
# ### Careers 2018

# %%
carers_by_gender = pd.read_csv('./carers_by_sex.csv')
carers_by_gender.head()
# Out:
#   Age group (years)  Males (%)  Females (%)  Persons (%)
# 0      Less than 15        0.8          1.2          1.0
# 1             15-24        6.0          6.2          6.0
# 2             25-34        6.4          8.2          7.3
# 3             35-44        8.2         14.3         11.3
# 4             45-54       14.2         21.2         17.7

# %%
carers_by_gender.dtypes
# Out:
# Age group (years)     object
# Males (%)            float64
# Females (%)          float64
# Persons (%)          float64
# dtype: object

# %%
carers_by_gender.to_sql('carers_by_gender', con=engine,  if_exists='replace');

# %% [markdown]
# ### Reason not in labour force by gender 2008

# %%
reason_not_labour_force = pd.read_csv('./reason_not_labour_force.csv')
reason_not_labour_force.head()
# Out:
#          Year Main reason not currently in the labour force  Males  Females
# 0  2008-01-01                              Has job to go to    0.6      0.4
# 1  2008-01-01              Own ill health/injury/disability   42.0     19.7
# 2  2008-01-01                                Study purposes    6.9      4.5
# 3  2008-01-01                       No need to work/retired   35.7     30.3
# 4  2008-01-01              Welfare payments may be affected    0.2      0.3

# %%
reason_not_labour_force['Year'] = pd.to_datetime(reason_not_labour_force['Year'].astype(str),format='%Y/%m/%d')

# %%
reason_not_labour_force.dtypes
# Out:
# Year                                             datetime64[ns]
# Main reason not currently in the labour force            object
# Males                                                   float64
# Females                                                 float64
# dtype: object

# %%
reason_not_labour_force.to_sql('reason_not_labour_force', con=engine,  if_exists='replace');

# %% [markdown]
# ### Average income by gender from 1994

# %%
super_balance_gender = pd.read_csv('./average_account_superannuation_gender_year_2014_2020.csv')
super_balance_gender.head()
# Out:
#          Year       Age Average account balance $ Male  \
# 0  2014-01-01  under 18                          6,815
# 1  2014-01-01     18-24                          7,528
# 2  2014-01-01     25-29                         22,064
# 3  2014-01-01     30-34                         41,873
# 4  2014-01-01     35-39                         63,791
#
#   Average account balance $ Female
# 0                            4,761
# 1                            6,004
# 2                           18,804
# 3                           33,726
# 4                           49,534

# %%
super_balance_gender.columns
# Out:
# Index(['Year', 'Age', 'Average account balance $ Male',
#        'Average account balance $ Female'],
#       dtype='object')

# %%
super_balance_gender['Average account balance $ Male'] = super_balance_gender['Average account balance $ Male'].str.replace(',','.')
super_balance_gender['Average account balance $ Female'] = super_balance_gender['Average account balance $ Female'].str.replace(',','.')

# %%
super_balance_gender['Year'] = pd.to_datetime(super_balance_gender['Year'].astype(str), format='%Y/%m/%d')

# %%
super_balance_gender.head()
# Out:
#         Year       Age Average account balance $ Male  \
# 0 2014-01-01  under 18                          6.815
# 1 2014-01-01     18-24                          7.528
# 2 2014-01-01     25-29                         22.064
# 3 2014-01-01     30-34                         41.873
# 4 2014-01-01     35-39                         63.791
#
#   Average account balance $ Female
# 0                            4.761
# 1                            6.004
# 2                           18.804
# 3                           33.726
# 4                           49.534

# %%
super_balance_gender.dtypes
# Out:
# Year                                datetime64[ns]
# Age                                         object
# Average account balance $ Male             float64
# Average account balance $ Female           float64
# dtype: object

# %%
super_balance_gender['Average account balance $ Male'] = super_balance_gender['Average account balance $ Male'].astype(float)
super_balance_gender['Average account balance $ Female'] = super_balance_gender['Average account balance $ Female'].astype(float)

# %%
super_balance_gender.to_sql('super_balance_gender', con=engine,  if_exists='replace');

# %% [markdown]
# ### Reason to left job for retirment

# %%
reason_to_left_job_retired = pd.read_csv('./reason_to_left_job_retired.csv')
reason_to_left_job_retired.head()
# Out:
#                          Reason for ceasing last job  Less than 55 Male  \
# 0             Retrenched/dismissed/no work available               32.6
# 1                     Temporary/seasonal/holiday job               13.9
# 2      Own business closed down for economic reasons                4.9
# 3  Own business closed down or sold for other tha...               15.1
# 4  Unsatisfactory work arrangements/wanted to wor...                6.5
#
#    55–59 Male  60–64 Male  65–69 Male  70 and over Male  \
# 0        24.2        51.5        23.0               4.0
# 1         7.7        14.6         2.3               7.8
# 2         6.8         5.3         5.5               3.0
# 3         7.0         8.0         6.4               6.2
# 4         6.5         5.1         1.5               0.9
#
#    Average age at retirement Male  Less than 55 Female  55–59 Female  \
# 0                            59.0                 43.2          31.0
# ...

# %%
reason_to_left_job_retired.columns
# Out:
# Index(['Reason for ceasing last job', 'Less than 55 Male', '55–59 Male',
#        '60–64 Male', '65–69 Male', '70 and over Male',
#        'Average age at retirement Male', 'Less than 55 Female', '55–59 Female',
#        '60–64 Female', '65–69 Female', '70 and over Female',
#        'Average age at retirement Female'],
#       dtype='object')

# %%
reason_to_left_job_retired = pd.melt(reason_to_left_job_retired, id_vars =['Reason for ceasing last job'], value_vars =['Less than 55 Male', '55–59 Male',
       '60–64 Male', '65–69 Male', '70 and over Male',
       'Average age at retirement Male', 'Less than 55 Female', '55–59 Female',
       '60–64 Female', '65–69 Female', '70 and over Female',
       'Average age at retirement Female'])

# %%
reason_to_left_job_retired.head()
# Out:
#                          Reason for ceasing last job           variable  value
# 0             Retrenched/dismissed/no work available  Less than 55 Male   32.6
# 1                     Temporary/seasonal/holiday job  Less than 55 Male   13.9
# 2      Own business closed down for economic reasons  Less than 55 Male    4.9
# 3  Own business closed down or sold for other tha...  Less than 55 Male   15.1
# 4  Unsatisfactory work arrangements/wanted to wor...  Less than 55 Male    6.5

# %%
reason_to_left_job_retired.dtypes
# Out:
# Reason for ceasing last job     object
# variable                        object
# value                          float64
# dtype: object

# %%
reason_to_left_job_retired = reason_to_left_job_retired.rename(columns={'variable': 'Age & Sex'})

# %%
reason_to_left_job_retired.head()
# Out:
#                          Reason for ceasing last job          Age & Sex  value
# 0             Retrenched/dismissed/no work available  Less than 55 Male   32.6
# 1                     Temporary/seasonal/holiday job  Less than 55 Male   13.9
# 2      Own business closed down for economic reasons  Less than 55 Male    4.9
# 3  Own business closed down or sold for other tha...  Less than 55 Male   15.1
# 4  Unsatisfactory work arrangements/wanted to wor...  Less than 55 Male    6.5

# %%
reason_to_left_job_retired.to_sql('reason_to_left_job_retired', con=engine,  if_exists='replace');

# %% [markdown]
# ### Status Work for Non Qualification 2019 to 2021

# %%
status_work_nonqual = pd.read_csv('./non_quali_work_status_gender.csv')
status_work_nonqual.head()
# Out:
#                Work Status  Males %  Females %
# 0       Employed full-time     68.6       44.6
# 1       Employed part-time     12.2       30.1
# 2           Employed total     80.8       74.7
# 3               Unemployed      3.3        3.0
# 4  Not in the labour force     15.8       22.4

# %%
status_work_nonqual.dtypes
# Out:
# Work Status     object
# Males %        float64
# Females %      float64
# dtype: object

# %%
status_work_nonqual.to_sql('status_work_nonqual', con=engine,  if_exists='replace');

# %% [markdown]
# ### Field of Job

# %%
field_of_job_2021 = pd.read_csv('./field_of_job_2021.csv')
field_of_job_2021.head()
# Out:
#                                     Field of Job  Males %  Females %
# 0                  Natural and physical Sciences     48.4       51.4
# 1                         Information technology     74.5       25.2
# 2           Engineering and related technologies     91.0        8.9
# 3                      Architecture and building     85.6       14.2
# 4  Agriculture environmental and related studies     66.3       33.4

# %% [markdown]
# ### Engaged at work and/or study

# %%
engaged_work_study = pd.read_csv('./Engaged_work_study.csv')
engaged_work_study.head()
# Out:
#                Engagement  Males 15-24  Females 15-24  Males 25-44  \
# 0           Fully engaged         81.2           81.2         82.4
# 1       Partially engaged          9.1           11.3          8.6
# 2  No study or employment          9.7            7.5          9.0
#
#    Females 25-44  Males 45-74  Females 45-74
# 0           55.0         54.0           32.7
# 1           26.3         11.2           24.3
# 2           18.6         34.8           43.1

# %%
engaged_work_study.columns
# Out:
# Index(['Engagement', 'Males 15-24', 'Females 15-24', 'Males 25-44',
#        'Females 25-44', 'Males 45-74', 'Females 45-74'],
#       dtype='object')

# %%
engaged_work_study = pd.melt(engaged_work_study, id_vars =['Engagement'], value_vars =['Males 15-24', 'Females 15-24', 'Males 25-44',
       'Females 25-44', 'Males 45-74', 'Females 45-74']);

# %%
engaged_work_study.to_sql('engaged_work_study', con=engine,  if_exists='replace');

# %% [markdown]
# ### Bachelor Degree by Gender

# %%
bachelor_degree_gender_2021 = pd.read_csv('./bachelor_degree_gender_2021.csv')
bachelor_degree_gender_2021.head()
# Out:
#            Age  Males %  Females %
# 0  15-24 years      8.3       13.2
# 1  25-34 years     36.6       50.4
# 2  35-44 years     41.3       49.0
# 3  45-54 years     33.4       36.9
# 4  55-64 years     23.5       26.0

# %%
bachelor_degree_gender_2021.to_sql('bachelor_degree_gender_2021', con=engine,  if_exists='replace');

# %% [markdown]
# ### Weekly Earning by industry 2021

# %%
weekly_earning_industry_2021 = pd.read_csv('./weekly_earning_industry_2021.csv')
weekly_earning_industry_2021.head()
# Out:
#          Year                                  Industry  Males ($)  \
# 0  2021-11-01                                    Mining     2724.9
# 1  2021-11-01                             Manufacturing     1601.5
# 2  2021-11-01  Electricity, gas, water & waste services     2007.6
# 3  2021-11-01                              Construction     1776.2
# 4  2021-11-01                           Wholesale trade     1720.4
#
#    Females ($)
# 0       2306.3
# 1       1394.9
# 2       1850.8
# 3       1468.0
# 4       1441.6

# %%
weekly_earning_industry_2021.dtypes
# Out:
# Year           datetime64[ns]
# Industry               object
# Males ($)             float64
# Females ($)           float64
# dtype: object

# %%
weekly_earning_industry_2021['Year'] = pd.to_datetime(weekly_earning_industry_2021['Year'].astype(str), format='%Y/%m/%d')

# %%
weekly_earning_industry_2021.to_sql('weekly_earning_industry_2021', con=engine,  if_exists='replace');

# %% [markdown]
# ### Weekly Earning by Industry 2020

# %%
weekly_earning_industry_2020 = pd.read_csv('./weekly_earning_industry_2020.csv')
weekly_earning_industry_2020.head()
# Out:
#          Year                                  Industry  Persons ($)  \
# 0  2021-11-01                                    Mining       2633.2
# 1  2021-11-01                             Manufacturing       1555.9
# 2  2021-11-01  Electricity, gas, water & waste services       1944.1
# 3  2021-11-01                              Construction       1629.4
# 4  2021-11-01                           Wholesale trade       1578.4
#
#    Males ($)  Females ($)
# 0     2695.9       2295.8
# 1     1599.1       1397.8
# 2     1986.8       1790.0
# 3     1668.0       1394.4
# 4     1641.5       1427.3

# %%
weekly_earning_industry_2020['Year'] = pd.to_datetime(weekly_earning_industry_2020['Year'].astype(str), format='%Y/%m/%d')

# %%
weekly_earning_industry_2020.to_sql('weekly_earning_industry_2020', con=engine,  if_exists='replace');

# %% [markdown]
# ### Weekly Earning Industry 2019

# %%
weekly_earning_industry_2019 = pd.read_csv('./weekly_earning_industry_2019.csv')
weekly_earning_industry_2019.head()
# Out:
#          Year                                  Industry  Males $  Females $
# 0  2019-11-01                                    Mining     2668       2302
# 1  2019-11-01                             Manufacturing     1504       1349
# 2  2019-11-01  Electricity, gas, water & waste services     1940       1732
# 3  2019-11-01                              Construction     1683       1389
# 4  2019-11-01                           Wholesale trade     1654       1386

# %%
weekly_earning_industry_2019['Year'] = pd.to_datetime(weekly_earning_industry_2019['Year'].astype(str), format='%Y/%m/%d')

# %%
weekly_earning_industry_2019.to_sql('weekly_earning_industry_2019', con=engine,  if_exists='replace');
